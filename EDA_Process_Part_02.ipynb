# %%
# Import pandas,Numpy,Seaborn,Matplotlib liabrary
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read file in csv,excel,json,text and they define python format read data
df=pd.read_excel(r"c:\Users\ADMIN\Downloads\icc_dataset (1).xlsx")

# %% [markdown]
# # Step 3: Exploratory Data Analysis (EDA)

# %% [markdown]
# # 📌 EDA Checklist: Data-Driven Ad Campaign Optimization
#
# ---
#
# ## 🟢 3.1: Business Understanding
#
# - [ ] Business Problem Revisit
# - [ ] Identify KPIs to analyze (CTR, ROAS, CVR, etc.)
# - [ ] Define business goals: engagement, conversion, revenue
#
# ---

# %%
# Find the all calculation add column in any field
# Basic KPI Calculations with correct column names
df['CTR_calc'] = (df['clicks'] / df['impressions']) * 100
df['CVR_calc'] = (df['conversions'] / df['clicks']) * 100
df['ROAS_calc'] = df['revenue'] / df['cost']
df['CPC_calc'] = df['cost'] / df['clicks']

# Show calculated KPIs stats
df[['CTR_calc', 'CVR_calc', 'ROAS_calc', 'CPC_calc']].describe()

# %% [markdown]
# ## 🟢 3.2: Data Structure & Quality
#
# - [ ] Understand Dataset Shape, Types (`.info()`, `.describe()`)
# - [ ] Identify duplicates, unexpected values
# - [ ] Missing Data Analysis (Nulls %, pattern analysis)
# - [ ] Outlier Detection (Boxplot, IQR, Z-score)
# - [ ] Skewness & Kurtosis (For transformation needs)
#
# ---

# %%
dUplicat_Row=df.duplicated()

# %%
# identifying unexpected value
print(df[df['column_name'] < 0])
print(df[df['column_name'] < 0])
print(df[df['column_name'] < 0])

# %%
# Visual Pattern Analysis (Heatmap)
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Data Heatmap")
plt.show()

# %%
# Visual To boxplt
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['ctr'])
plt.title("CTR Boxplot")
plt.xlabel("ctr")
plt.show()

# %%
df.columns
# Out:
# Index(['Tournament', 'Year', 'Venue', 'Winner', 'Runner-up', 'Semi-Finalists',
#        'Match_Winner_Final', 'Player_of_Tournament'],
#       dtype='object')

# %%
#  Countplot (बार ग्राफ) — श्रेणीवार किती डेटा पॉइंट्स आहेत ते दाखवतो:
# countplot visual the data off count line 

plt.figure(figsize=(8,5))
sns.countplot(x='Tournament', data=df)
plt.title(" World cup all format")
plt.xlabel("Platform")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
#  Pie Chart — श्रेणींचं टक्केवारीनुसार वितरण दाखवतो:
plt.figure(figsize=(6,6))
df['Winner'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Winner Distribution")
plt.ylabel('')
plt.show()

# %%
# Define scatterplots
plt.figure(figsize=(18, 12))
plt.subplot(2, 3, 1)
sns.scatterplot(data=df, x='impressions', y='clicks')
plt.title('Impressions vs Clicks')

# %%
# only numeric columns
# Select only numerical columns
numerical_df = df.select_dtypes(include='number')

# Calculate correlation matrix
correlation_matrix = numerical_df.corr()

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()
